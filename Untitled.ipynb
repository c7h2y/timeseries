# %%
# !pip install matplotlib

# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/user/miniconda3/envs/timeseries/lib/python3.10/site-packages (from statsmodels) (2.1.3)
# Collecting scipy!=1.9.2,>=1.8 (from statsmodels)
#   Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/user/miniconda3/envs/timeseries/lib/python3.10/site-packages (from statsmodels) (2.3.1)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in /home/user/miniconda3/envs/timeseries/lib/python3.10/site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/user/miniconda3/envs/timeseries/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/user/miniconda3/envs/timeseries/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/user/miniconda3/envs/timeseries/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/user/miniconda3/envs/timeseries/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Downloading statsmodels-0.14.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 50.8 MB/s eta 0:00:000:00:01
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
# Installing collected packages: scipy, patsy, statsmodels
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [statsmodels]━━━━━━ 2/3 [statsmodels]
# Successfully installed patsy-1.0.1 scipy-1.15.3 statsmodels-0.14.5

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Generate random time-series data
np.random.seed(42)
dates = pd.date_range(start='2022-01-01', periods=100, freq='D')
values = np.random.randn(100).cumsum()

# Create a DataFrame from the generated data
data = pd.DataFrame({'date': dates, 'value': values})

# Set the 'date' column as the index
data.set_index('date', inplace=True)

# Plot the time-series data
plt.plot(data.index, data['value'])
plt.xlabel('Time')
plt.ylabel('Value')
plt.xticks(rotation = 45)
plt.title('Time Series Data')
plt.show()

# %%
# Augumented Dickey-Fuller test : ADF
# Kwiatkowski-Phillips-Schmidt-Shin (KPSS) test

# %%
from statsmodels.tsa.stattools import adfuller

# Assuming 'data' is the time series data
result = adfuller(data)
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: -1.3583317659818992
# p-value: 0.6020814791099098

# %%
# Autocorrelation : 自己相関
# Partial autocorrelation : 偏自己相関関数

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(data)
plot_pacf(data)
plt.show()
